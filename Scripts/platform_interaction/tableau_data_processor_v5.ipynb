# %%
# %reset

import matplotlib.pyplot as plt
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
import numpy as np
import csv
import datetime
import time
from datetime import datetime
from datetime import timedelta
import dill

###set working directory
os.chdir('/Users/Matt1/Box/NAMS - Internal MK group Planning/Research Study/NAMS_paper/Data/platform_data/NAMS/platform_interaction/Oral Sessions')

dill.load_session(os.getcwd() + '/clean_webinar_data.db')
data=webinar_data_all

#specify timestamps with 1 minute frequency for each conference day
#Day 1
start1=pd.Timestamp(2020, 5, 18, 10, 0, 0)
end1=pd.Timestamp(2020, 5, 18, 13, 15, 0)
timestamps1 = pd.date_range(start=start1,end=end1,freq='min')

#Day 2
start2=pd.Timestamp(2020, 5, 19, 10, 0, 0)
end2=pd.Timestamp(2020, 5, 19, 12, 15, 0)
timestamps2 = pd.date_range(start=start2,end=end2,freq='min')

#Day 3
start3=pd.Timestamp(2020, 5, 20, 10, 0, 0)
end3=pd.Timestamp(2020, 5, 20, 15, 0, 0)
timestamps3 = pd.date_range(start=start3,end=end3,freq='min')

#Day 4
start4=pd.Timestamp(2020, 5, 21, 10, 0, 0)
end4=pd.Timestamp(2020, 5, 21, 15, 0, 0)
timestamps4 = pd.date_range(start=start4,end=end4,freq='min')

stamps_total=timestamps1.append(timestamps2)
stamps_total=stamps_total.append(timestamps3)
stamps_total=stamps_total.append(timestamps4)

#create list of unique participants
participants = data['Participant'].tolist()
participants=list(set(participants))

#create dataframe of with columns for unique participants
tseries = pd.DataFrame(columns = participants)
#set index to timestamps for conference days
tseries=tseries.reindex(stamps_total)
#set all table values to 0
for col in tseries.columns:
    tseries[col].values[:] = 0

#cycle through each unique participant
for person in tseries.columns:
    print(person)
    #get data for unique participant
    person_data = data.loc[data['Participant']==person]
    #cycle through each timestamp of conference
    for stamp in tseries.index:
        #cycle through each logged entry or exit stamp for unique participant
        for row in person_data.index:
            #check if conference timestamp of interest is within the range of this login
            if stamp > person_data.loc[row,'Join Time'] and stamp < person_data.loc[row,'Leave Time']:
                    #list the room that this unique particpant was in at this timestamp
                    tseries.loc[stamp,person] = person_data.loc[row,'Room']

#create columns for rooms to sum the number of participants in attendance
tseries['Room1']=0
tseries['Room2']=0
tseries['Room3']=0
tseries['Room4']=0
tseries['Room5']=0    
#cycle through conference timestamps and sum the number of participants in each room at the timestamp
for stamp in tseries.index:
    tseries.loc[stamp,'Room1'] = sum(1 for i in list(tseries.loc[stamp,:]) if i == 1)
    tseries.loc[stamp,'Room2'] = sum(1 for i in list(tseries.loc[stamp,:]) if i == 2)
    tseries.loc[stamp,'Room3'] = sum(1 for i in list(tseries.loc[stamp,:]) if i == 3)
    tseries.loc[stamp,'Room4'] = sum(1 for i in list(tseries.loc[stamp,:]) if i == 4)
    tseries.loc[stamp,'Room5'] = sum(1 for i in list(tseries.loc[stamp,:]) if i == 5)

#sum the attendance in all five webinar rooms
tseries['Total'] = tseries['Room1']+tseries['Room2']+tseries['Room3']+tseries['Room4']+tseries['Room5']

#reformat dataframe for importing to Tableau
tab_data=pd.DataFrame()
room1=pd.DataFrame(tseries['Room1'])
room1=room1.rename(columns={"Room1":"Quantity"})
room1['Room']='Room1'
tab_data=tab_data.append(room1)
room2=pd.DataFrame(tseries['Room2'])
room2=room2.rename(columns={"Room2":"Quantity"})
room2['Room']='Room2'
tab_data=tab_data.append(room2)
room3=pd.DataFrame(tseries['Room3'])
room3=room3.rename(columns={"Room3":"Quantity"})
room3['Room']='Room3'
tab_data=tab_data.append(room3)
room4=pd.DataFrame(tseries['Room4'])
room4=room4.rename(columns={"Room4":"Quantity"})
room4['Room']='Room4'
tab_data=tab_data.append(room4)
room5=pd.DataFrame(tseries['Room5'])
room5=room5.rename(columns={"Room5":"Quantity"})
room5['Room']='Room5'
tab_data=tab_data.append(room5)

#Create tableau_data export folder if it doesn't exist
if not os.path.exists(os.getcwd() + '/tableau_data'):
    os.makedirs(os.getcwd() + '/tableau_data')

#Export time series of room attendance and reformatted data for tableau
tab_data.to_csv(os.getcwd() + '/tableau_data/tableau_data.csv',index_label='Timestamp')
tseries.to_csv(os.getcwd() + '/tableau_data/tseries_data.csv',index_label='Timestamp')

#Export environment as database file
dill.dump_session(os.getcwd() + '/tableau_data/attendees_per_session.db')
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Yuanhao Li
# Chetan Sharma
# Alberto Tena
# Manish Kumar
# Alec Lanter
# John Thompson
# shun shimura
# shudipto
# Xiaoli Ma
# Humeyra
# Jack Gilron
# Hanqing Fan
# lgiorno
# Levente Cseri
# Zain Ali
# Debraliz
# Trouba
# Ron Kasher
# Stephanie McCartney
# Jaime Idarraga-Mora
# sankar
# abdulaziz alammar
# Mukta Hardikar
# xueshan
# Alyson Beldon
# Jignesh
# Jinsheng
# Stephen Meckler# PARC
# Corey Iwane-Lee
# Don Stookey
# Evyatar Shaulaky
# Priyanka Manchanda
# jsh zhou
# Jesus Manzano Garcia
# Jessica Shu
# A0711191
# Adam Atia
# joe
# Joe
# Gray Dennis
# Wouter Nielen
# Sap
# Christine Duval
# Elizabeth Jackson
# Xin Liu
# shiqi
# V
# Albert
# Nick Yearout
# Kumar Varoon Agrawal
# Weiliang Bai
# David Ladner
# Jincheng Lou
# Eric Ledieu
# Eyad Qasem
# Subarna Kole
# jeremy
# Jon Brant
# Yang Yang
# Ryan Kingsbury
# Marylaura Lind Thomas
# Caleb Funk - DuPont
# Christopher Arnusch
# Hai Anh Le Phuong
# KAI YANG
# jet
# Salman Bin Kashif
# Si Li
# Ayse Asatekin
# Vincent Nguyen MTR
# Rajinder Singh
# al9188
# Hao Tang
# 이지은
# Qi
# Kuang-Jung
# Leticia Santos
# Jinting Hu
# Carl Jones
# Rahul Dutta
# Menachem Elimelech
# Junwei Wang
# Shaofeng Ran
# Phillip Sandman
# Shun Shimura
# Santiago Romero
# Elisabeth
# Yuanzhe Liang
# David Saabas
# Mike Fornes
# sirkar
# ahall
# Mojtaba Rezaei
# Carson Bechtel
# Lauren T
# Mansour Saberi
# Ryan LaRue
# YORAM COHEN
# Lenovo
# Heyang Qi
# Joshua Osuofa
# manchap
# Zuo Zhou
# Xinhong Liu
# Yuxuan Huang
# Soryong (Ryan) Chae
# Andrew Zydney
# Christoph Schlaich
# Yuexiao Shen
# Riley Vickers
# Marta Hatzell
# Lidietta Giorno
# Mikayla Armstrong
# Abhishek
# Albert Schnieders
# Efecan Pakkaner
# Phiwat Klomkaew
# Marc Lavine
# Tirtha-DuPont_Water
# Shabnam
# Maria-Chiara Ferrari
# xianghong
# Snodgrass# Christopher
# Yuhao (Sam) Du
# Jiangtao
# Stephen Meckler
# Steve Jons
# Tiefan Huang
# Meny
# Katie Li-Oakey
# Munir Cheryan
# Soryong Chae
# Irshad Baig
# Mike Detisch
# Vlad Tarabara
# Tiezheng Tong
# prashant shrikhande
# jg
# Xin Qian
# Clare Wunder
# Itzel
# Family Carbrello
# Fereshteh
# Robert McNair
# Scott Zero
# kerrihickenbottom
# Luca Mazzaferro
# Dana
# Ainur Lingoda
# Fangzhou Liu
# Shouliang Yi
# Jeffrey McCutcheon
# Katherine Mizrahi
# CHIA MIANG KHOR
# Dave Latulippe
# Jacob Johnston
# gary
# Bowen
# Zixuan Wang
# John Hodul
# Jishan Wu
# amirhooshang
# Mi
# Laxmicharan Samineni
# Leticia Santos de Souza
# Jie Shen
# e1236836
# Joey
# Yizhou Zhang
# Lie MENG
# Alexander Bridge
# Cody Ritt
# Kayla Roberta Storme
# R. Dalpke
# KEVIN REIMUND
# Ji Hoon Kim
# JPalmero
# Pavithra Narayanan
# Milad Esfahani
# Sunxiang Zheng
# xushu
# Zach
# David Hicks
# P Hao
# Elham Abaie
# Valentina-Elena Musteata
# Luis Francisco Villalobos
# Lars Kohler
# Hyeonji Oh
# Anna Fraser
# Fanglei Zhou
# holden lai
# Dave Brewster
# Mani Korah
# meagan mauter
# Erda Deng
# Nan Zhang
# zang
# liubi
# Woochul Song
# LIUJ0I
# Jialing Xu
# MeMorris
# Dave
# yufeng
# Mostafa Nassr
# JGamler
# Hiroki Fukuda
# Tianchi
# Saheed Bukola
# Oguz Karvan
# CSchlaic
# Erik Hoving
# Olivia Lenz
# fe9493
# Dana Dutczak
# Pablo Emmanuel Alvarez Alonso
# Jovan K.
# Guy Ramon
# Shabnam Lotfi
# heng-yu chi
# Arezou Anvari
# Yao Ma
# Tayler Hedtke
# Bryan Beckingham
# Priyesh
# Dean Welsh - DuPont
# Ji-Eun Lee
# Yusi Li
# Raheleh Daneshpour
# (DB) D. Bhattacharyya
# Priyanka Suresh
# Haley
# Zihan Huang
# Andrew Fix
# Jose Agustin Epstein
# Yuhang Fang
# DAVID JASSBY
# Anne Oberlink
# PARC
# Michelle
# Ruilan Guo
# Leland Vane
# deng@NTNU
# Faheem Akhtar
# Oscar OVALLE ENCINIA
# Zahra Anari
# 16307473634
# Vasiliki Karanikola
# Gergo Ignacz
# Fan.Worley
# Abhimanyu Das
# alexi
# Evangelos
# Walt Kosar
# Monong Wang
# Abada# Bilal Saad A
# Sharon Sharick
# Francesco Maria Benedetti
# Cheng
# Grigorios Panagakos
# Gupta# Kunal
# admin
# Haley White
# Bezawit Getachew
# Jacob
# Minh Nguyen
# VA
# William
# Abaynesh Gebreyohannes
# Oscar OVALLE
# Shouhong Fan
# Mostapha Dakhchoune
# Mahdi Shahrooz
# Thomas Schafer
# Hua
# Ivy Wu
# WSalim
# Sage Hiibel
# Tianchi Cao
# Elif Nur Durmaz (UTwente)
# Joe H
# William Trinh
# jean
# Shu Heredia
# Synder Filtration
# James Baker
# Tejas
# Mackenzie Anderson
# Raj Singh
# M.K. Mani
# Giuseppe Genduso
# Pouyan Pourmovahed
# 13149953436
# Hossein Nouri
# Pauline Zimmermann
# erik.hoving@evonik.com
# Mahmood Jebur
# Jan Steckel
# Chulsung Bae
# Anna Malakian
# Castro
# Jeremy Lewis
# Henning Vieker
# Jonathan Brant
# Heng-Yu Chi
# Adi Gelb
# Paek# Changyub
# william trinh
# desalination
# Bianca C
# Neel Rangnekar
# Linlin Zang
# Humeyra Ulusoy Erol
# Zora
# sankhajit pal
# Ed.Sanders
# MICHAEL KLACZKO
# michelle
# Yujiao Li
# M C
# Mikayla
# Chunyi Li
# John Smart
# Mahati Chintapalli
# Zoltan A. Fekete
# Noel Devaere
# Yao
# suhao
# Evan Hatakeyama
# Prashant Shrikhande
# Yash T
# Amogh Meshram
# Wenli Jiang
# Sarah Pate
# Yumeng Zhao
# Mihai Barboiu
# Giuseppe Vitola
# Petrus Cuperus
# Jong Geun SEONG
# Ngai Yin Yip
# Elsa Lasseuguette
# Sam Lounder
# MOh
# Taigyu Joo
# Pieter
# Edward Wazer
# Sang Lee
# Wael Elwali
# jiaxi jiang
# Katherine Zodrow - Montana Tech
# Ainur Yerzhankyzy
# Noemi Collado
# lins6
# Kinnari Malav Shah
# JOE
# Brandon Clark
# Luca Kim
# SHAHJJ
# sharon bone
# akriti
# Tiger
# Kai YANG
# linlin zang
# Christian Wingate
# Piash
# Sifat
# Gazelle
# Jovan Kamcev
# hasan sohi
# Mauricio Dantus
# Zach Binger
# HaoyuWu_
# RD
# Linh
# Tejaswi Nori
# Sam Butcher
# Ronald Vogler
# xuqing
# Ja-young Koo
# Ruoyu Wang
# Geoff Geise
# Amir Hooshang
# duong
# Razi Epsztein
# David Sholl
# Yang Han
# 16824087245
# Laurel Bitterman
# oishisanyal
# Oishi Sanyal
# Matthew Rivera
# Haiqing Lin
# Michelle Lehmann
# Melanie Merrick
# Hee Jeung Oh
# Dave Hopkinson
# Matthew Skiles
# Ryan DuChanois
# Maria Teresa Guzman Gutierrez
# Aroshe Black Belt
# XLM
# tphak
# E
# NC
# kumar.agrawal@epfl.ch
# Andrew Morgan
# Yi Zhou
# Trisha Nickerson
# Robert Field
# Katie O'Harra
# Camille Violet
# Julian Richardson
# James Tran
# Sebastian Hernandez
# szemicha
# ruoyu
# David Warsinger
# Abhishek Dutta
# Bofan Li
# Rollie Mills
# Bruce Hinds
# MOHAN QIN
# Riko Korzetz
# yogi
# Moonjoo Lee
# Fatima Adhiam
# cl
# zx3682
# ignaczg
# Mikayla Yoder
# Emmanuel Oni
# Moh
# Jong Geun Seong
# Pang# Ruizhi
# Sachin
# Rahul Sujanani
# Prity BL
# Fei Liu
# Nicholas Silva
# Jeff McCutcheon
# irene
# Bryan Pamintuan
# Chris Arges
# Weiyi Li
# Banan
# Youngjoo Lee
# Michael Zelner
# Katherine Zodrow
# Bianca Chaves
# Donna Hildebrandt
# Sandra Aristizabal
# da7632
# Phuong Trinh
# Shaofei Wang@MIT
# Shuyana Heredia
# Zhifeng Zhang
# meiqi
# Spencer Schwab
# Irene Zou
# JING
# boya xiong
# Orlando Coronell
# Wan-Ni Wu
# Péter Kisszékelyi
# Minh N. Nguyen
# Patrick Saboe
# babidemi
# Joby
# Jonathan Aubuchon Ouimet
# Rukmini Lobo
# L. Sun
# Manoj
# Marie-Eve Langevin
# Jon Maisonneuve
# John Pellegrino
# Slava Freger
# Gheorghe
# Jay Liu
# Xiaofei Huang
# Chetan
# Ting Yu Chen
# db
# Verweij
# David Latulippe
# jinsheng
# Edwin Torres Cuevas
# DurmazEN
# Feihu Wang
# Carsten FH
# sanjana
# Songhua Liu
# Hai Anh
# Ben Sundell
# andrea
# Michael Geitner
# Arash Emdadi
# Lei Zheng
# gzshao
# Trisha
# Surendar Venna
# Mohammed Alhussaini
# Chase Krieger
# Melinda Jue
# Sean Zheng
# milad Yavari
# Ben Bikson
# Bshuldes
# HYEJIN LEE
# Joe DeAngelis
# Ryan Fouad
# Hannah Holmes
# Jerry Lin
# Sandra Córdoba
# Jet Yeo
# Ben
# Benjamin Shuldes
# Eileen Dawson
# Bailey Vaillancourt
# Shaofei Wang
# William Phillip
# Hans
# Jong Geun
# Justin Easa
# rachel.squires
# Greg Newbloom
# adam kratochvil
# O.Lenz
# Christopher Arges
# John
# Tony Straub
# Lie Meng
# Travis Pyrzynski
# Amir Taheri
# Kirti
# Horacio Lopez Marques
# A6192581
# Ramesh Bhave
# Jim McGrath
# Conrad
# Kartikeya Kekre
# raziepsztein@technion.ac.il
# George Wang
# Fadi Tantish
# Melissa Larocque
# Li Wang
# Dongwoo Suh
# Nobuyo Watanabe
# adi gelb
# Akshay Rao
# Wan-Chi Lee
# Joanna Rivero
# Ronita Mathias
# Kirti Sankhala
# Banan Alhazmi
# Chris Stafford
# Ainur Sabirova
# Baoxia Mi
# Elisabeth Thomas
# Adam Oxley
# Hossein
# olivia lenz
# moh
# Armin Gölzhäuser
# Muhammad Irshad Baig
# Piran Kidambi
# Eline Pattyn - Porometer
# Mostapha Dakhchoune@epfl.ch
# Mary Laura Lind
# Dan Miller
# Limeimei Xu
# Lucy Mar Camacho
# Maedeh Nadimi
# Wilson Poon
# Liang-Kai Chu
# Wen Ma
# Andrea Achilli
# Zezhong Li
# Haamid Usman
# Ting-Yu Chen
# Minghui Qiu
# Hao
# FR
# NikoM_Lap
# Francois Perreault
# Victor Kusuma
# Baicang Liu
# Henry Tanudjaja
# shabanam
# Matthew Green
# Deepu
# Oguz Karvan (EMI-Twente/NL)
# Suzana Nunes
# Hajhayra
# Karl Longley
# Sudharshan Anandan
# Miguel
# Mikhail Stolov
# Fadhilah Alduraiei
# Isabel Escobar
# Ciara Avelina Lugo
# Justin J Teesdale
# Louis
# Prakhar Prakash
# carson bechtel
# James
# Yiming Liu
# Kelly Bye
# Zachary Binger
# Mike
# Shailesh Vidhate (W L Gore & Associates
# Sharon Lin
# Hyunhee Lee
# Weihua Qing
# Steven Pedersen
# Roy Bernstein
# Mohammad U. Shafiq
# Jiancai Li
# Yi Ren
# Sohum Patel
# Katherine
# Jie Shen-KAUST
# steve white
# Holly Haflich
# Ingo Pinnau
# Yiyang Ren
# Bianca C.
# Katie Dongmei Li-Oakey
# Xuechen Zhou
# Fei Cheng
# majda
# Mani
# Zachary P Smith
# Martin
# Lauren Greenlee
# Hannah Murnen
# Xinglin Lu
# Mahdi
# Duong Nguyen
# gali0002
# Mauricio
# Heloisa Westphalen
# Bianca
# Peter Fleming
# Xiaobo Dong
# CJ Kurth
# Mark Dudley
# Devin Shaffer
# Abhishek Gupta
# Clare
# Uwe Beuscher
# Mauricio Kleinberg
# SN
# Ke
# Abhishek123321
# Deepu Babu
# Steven Harrold
# Mohammad Sherafatmand
# Ian Billinge
# qliu
# Michael Detisch
# GShafer
# Hunter Himes
# Ashley Leibham
# Fadi
# ANDITYA RAHARDIANTO
# Yacine
# Yu-Heng
# Ricky Dong
# Richard D Noble
# Fateme Banihashemi
# E341098
# Jeff Quay
# Patrick
# Michele Galizia
# Elnaz Alebrahim
# Jamie Hestekin
# shiqi huang
# ondertekinalp
# John Trouba
# zuozhou
# songy
# Jiangtao Liu
# Husain Mithaiwala
# william tarpeh
# chris
# John T
# JG
# Zora Trask
# Kelly Conway
# Sarah Dischinger
# Chris Kane - W. L. Gore & Associates
# sl8516
# VAGARWAL
# Lieber# Austin R
# Jose Agustin
# Tom Gaborski
# Joyner Eke
# kerri hickenbottom
# izalantgios
# Aaron
# JongGeun
# Nitesh
# Habib# Mahpara
# Maria Kuchla
# 河合 隆一郎
# Wojciech Ogieglo
# Shudipto Dishari
# Jong
# Francisco Leniz
# Johnson# JR
# Jianfeng Zhou
# Mae Baird
# Kristofer Gleason
# Andreas Horner
# Stefan Chisca
# Alice Oliveira Aguiar
# yaoma
# Orlando Coronell Nieto
# Jingbo Wang
# Jamie FitzPatrick
# Zhangxin Wang
# Shrikanth Gowda
# Heloisa
# David Hopkinson
# Shu Xu
# Emily Thompson
# CLi
# Winston Ho
# Chao Tang
# Valerie Niemann
# Yian Chen
# Xiaoyi Chen
# Mohammad Farahani
# Nils Tilton
# Tao Wang
# Vy Tran (Jasmine)
# Shailesh Vidhate
# Adam Kratochvil
# Charisse Flerida Pasaje
# Reza Foudazi
# Lili Sun
# Hyunsik
# Albert Xiuyuan Wu
# Adi
# Zhiwei Jiang
# Jason
# Yang Liu
# Solomon Isu
# Sankar Ravichandran
# Marc
# Tim Bartholomew
# Glenn Lipscomb
# Michael Dugas
# Robin Studer
# Naama SM
# JC Davila Labastida
# Taliehsadat Alebrahim
# Ryan Lively
# Zahra
# Maura Sepesy
# Zhongyun Liu
# Peter Fiske
# HYJANG
# Shahriar Habib
# Qihui Qian
# Jongho Lee
# Sandra Aristizábal
# JC
# Matt Ringer
# Guozheng Shao
# shihong lin
# Muchu
# Matthew Davenport
# Lakshmeesha Upadhyaya
# Gengyi
# Yizhou
# Aristotle Grosz
# Masoud Aghajani
# tiezheng tong
# Santiago Romero-Vargas
# Zoli Fekete
# Joey DeAngelis
# Allyson McGaughey
# abenazer
# Onur Kas
# Steven Weinman
# Sophie De Respino
# Michele Crane
# William Mackay
# Gang Han
# Petra Kohler
# Serena Regina
# Esmat Maleki
# deng
# UNNATI RAO
# Yu-Ming Tu
# Renxi Jin
# Vincent Nguyen
# jinsheng zhou
# kaitlynbrickey
# Mark Roper
# Yifu Ding
# Sun
# Hornbostel# Katherine Mary
# R. Castro
# shabnam
# Kaitlyn Brickey
# Marcos Da Conceicao
# Yacine Feliachi
# amost
# Gergo
# jeasa@nd.edu
# JC Davila
# Luke Presson
# Mayur Ostwal
# Nitin Satav
# Shu XU
# Giuseppe
# Dave Hasse
# Scott Husson
# mjkiwaaz
# baohui
# Juan Jose Romero
# Alix Ineza
# Colin A. Wolden
# Alexander Dudchenko
# Sangsuk Lee
# Shengcun Ma
# wlee
# Mary Reilly
# christopher takacs
# Siamak Nejati
# Chenhao Yao
# Hua Jiang
# Ozan Erol
# Ke Meng
# Sarah Moussaddy
# Rangnekar# Neel D
# BONGYEON JUNG
# Shang-Lin Yeh
# David Bergsman
# Syed Z. Islam
# elasseug
# KALTHODG
# Abdulaziz alammar
# Meiqi Yang
# Thien Ngoc Tran
# Maurício Kleinberg
# Kishen Rafiz
# Chidambaram Thamaraiselvan
# Kai Chen
# Young Hee Yoon
# Irshad Kammakakam
# Casey O'Brien
# Lauren Tice
# Bradley Ladewig
# Xi Chen
# Chulsung
# Tina Carbrello
# Sancheyan
# Oguz Karvan (EMI-Twente)
# Chunqing Liu
# zezhong li
# Noelia Almodovar
